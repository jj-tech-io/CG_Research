# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# headers = ['Wavelength', 'Eumelanin', 'Pheomelanin']
df = pd.read_csv("/Users/joeljohnson/Documents/Github/CG_Research/PhysicalModels/AbsorptionValues 2.csv");
# print(df.head())

# Read in the data
# df = pd.read_csv('AbsorptionValues.csv')
# WaveLength = df.Wavelength
WaveLength = df.iloc[:,0]
Eumelanin = df.loc[:,'Eumelanin']
Pheomelanin = df['Pheomelanin'].to_numpy()

Baseline = df['Baseline'].to_numpy()

Reflectance = df['Reflectance'].to_numpy()

# Plot the data
plt.plot(WaveLength, Eumelanin)
plt.plot(WaveLength, Pheomelanin)
plt.plot(WaveLength, Baseline)

plt.plot()
plt.yscale('log')
plt.xscale('linear')
plt.xlim(400, 700)
# plt.ylim(0.015, 1000)


plt.title('Absorption Values')
plt.xlabel('Wavelength')
plt.ylabel('Absorption')
plt.legend(['Eumelanin', 'Pheomelanin', 'Baseline'])
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# headers = ['Wavelength', 'Eumelanin', 'Pheomelanin']
df = pd.read_csv("/Users/joeljohnson/Documents/Github/CG_Research/PhysicalModels/AbsorptionValues 2.csv");
# print(df.head())

# Read in the data
# df = pd.read_csv('AbsorptionValues.csv')
# WaveLength = df.Wavelength
WaveLength = df.iloc[:,0]
Eumelanin = df.loc[:,'Eumelanin']
Pheomelanin = df['Pheomelanin'].to_numpy()

Baseline = df['Baseline'].to_numpy()

Reflectance = df['Reflectance'].to_numpy()
plt.yscale('linear')
plt.xscale('linear')
plt.ylim(0,1)
plt.scatter(WaveLength, Reflectance)
#fitting the data
plt.show()
plt.plot(WaveLength, np.polyval(WaveLength, Reflectance), 'r')
plt.show()



x = np.empty(1000)
y = np.empty(1000)

plt.show()


for i in range(400,750,1000):
    #select reflectance value where wavelength = i
    # ref = Reflectance[np.where(WaveLength == i)]
    # refMin = np.argmax(refMin)
    # np.append(y, refMin)
    r = df[df.Wavelength==i ].to_numpy()


    if(r.size > 0):
        print(r)
        t = np.argmax(r)
        np.append(y, t)

  

plt.plot(x, np.polyval(x, y),'r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/c0/9r1vps757pgfst2gn8pz_ggr0000gn/T/ipykernel_51415/84146474.py in <module>
#      23 #fitting the data
#      24 plt.show()
# ---> 25 plt.plot(WaveLength, np.polyval(WaveLength, Reflectance, 2), 'r')
#      26 plt.show()
#      27
#
# <__array_function__ internals> in polyval(*args, **kwargs)
#
# TypeError: _polyval_dispatcher() takes 2 positional arguments but 3 were given
